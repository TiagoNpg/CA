# %% [markdown]
# # Visualize Image filter files

# %% [markdown]
# ## Original image

# %%
# import packages
from IPython.display import display,HTML
from PIL import Image

img = Image.open("dog8.pgm")
display(img)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=771x771>

# %% [markdown]
# ## Filtered image
#
# The filtered image is always saved as `filter.pgm`

# %%
img = Image.open("filter.pgm")
display(img)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=771x771>

# %% [markdown]
# ## Histogram
#
# The image histogram is always saved as `histogram.csv`

# %%
import pandas as pd

hist = pd.read_csv("histogram.csv")
hist.plot("level", title = "Histogram", legend = False, ylabel = "count", grid=True)
# Out:
# <Axes: title={'center': 'Histogram'}, xlabel='level', ylabel='count'>
